# %% [markdown]
# <a href="https://colab.research.google.com/github/gharinishankar/pyspark-learning/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark

# %% [markdown]
# from pyspark.sql import SparkSession
# spark= SparkSession.builder.appName("colab").getOrCreate()
# df=spark.createDataFrame([(1,"harini"),(2,"shankar")],["id","name"])
# df.show()

# %%
from pyspark.sql import SparkSession
spark= SparkSession.builder.appName("colab").getOrCreate()
df=spark.createDataFrame([(1,"harini"),(2,"shankar")],["id","name"])
df.show()
# Out:
# +---+-------+
# | id|   name|
# +---+-------+
# |  1| harini|
# |  2|shankar|
# +---+-------+

# %%
df=spark.createDataFrame([(1,"harini",25),(2,"shankar",30),(3,"meena",22)],["id","name","age"])
df.show()
# Out:
# +---+-------+---+
# | id|   name|age|
# +---+-------+---+
# |  1| harini| 25|
# |  2|shankar| 30|
# |  3|  meena| 22|
# +---+-------+---+

# %%
x=10
price=10.9
name="alice"
is_active=True

print(type(x))
print(type(price))
print(type(name))
print(type(is_active))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
scores = [78, 85, 92, 88]

print(scores[0])
print(len(scores))
# Out:
# 78
# 4

# %%
person = {
    "name":"sreeleela",
    "age":22,
    "city":"london"
}
print(person["age"])
# Out:
# 22

# %%
age=4
if age>=18:
  print("adult")
else:
  print("minor")
# Out:
# minor

# %%
from pyspark.sql.functions import when, col

df = df.withColumn(
    "status",
    when(col("age") >= 18, "Adult").otherwise("Minor")
)

df.show()
# Out:
# +---+-------+---+------+
# | id|   name|age|status|
# +---+-------+---+------+
# |  1| harini| 25| Adult|
# |  2|shankar| 30| Adult|
# |  3|  meena| 22| Adult|
# +---+-------+---+------+

# %%
df.select("name","age").show()
# Out:
# +-------+---+
# |   name|age|
# +-------+---+
# | harini| 25|
# |shankar| 30|
# |  meena| 22|
# +-------+---+
